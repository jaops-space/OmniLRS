# %%
from IPython import get_ipython
ipython = get_ipython()
if ipython is not None:
    ipython.run_line_magic('load_ext', 'autoreload')
    ipython.run_line_magic('autoreload', '2')
else:
    print("could not load extension")

# %%
import getpass

user = getpass.getuser()
from omni.isaac.kit import SimulationApp

# Set the path below to your desired nucleus server
# Make sure you installed a local nucleus server before this
# and that isaacsim is running
simulation_app = SimulationApp({"livesync_usd": f"omniverse://localhost/Users/{user}/test.usd"})
# Out:
# [Warning] [omni.isaac.kit]
# [Warning] [omni.isaac.kit] =========================== DEPRECATION WARNING ===========================
# [Warning] [omni.isaac.kit]
# [Warning] [omni.isaac.kit] Traceback (most recent call last):
# [Warning] [omni.isaac.kit] File '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/runpy.py', line 196
# [Warning] [omni.isaac.kit]   return _run_code(code, main_globals, None,
# [Warning] [omni.isaac.kit] File '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/runpy.py', line 86
# [Warning] [omni.isaac.kit]   exec(code, run_globals)
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel_launcher.py', line 18
# [Warning] [omni.isaac.kit]   app.launch_new_instance()
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/traitlets/config/application.py', line 1075
# [Warning] [omni.isaac.kit]   app.start()
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py', line 739
# [Warning] [omni.isaac.kit]   self.io_loop.start()
# [Warning] [omni.isaac.kit] File '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/exts/omni.isaac.core_archive/pip_prebundle/tornado/platform/asyncio.py', line 215
# [Warning] [omni.isaac.kit]   self.asyncio_loop.run_forever()
# [Warning] [omni.isaac.kit] File '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/asyncio/base_events.py', line 603
# [Warning] [omni.isaac.kit]   self._run_once()
# [Warning] [omni.isaac.kit] File '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/asyncio/base_events.py', line 1909
# [Warning] [omni.isaac.kit]   handle._run()
# [Warning] [omni.isaac.kit] File '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/asyncio/events.py', line 80
# [Warning] [omni.isaac.kit]   self._context.run(self._callback, *self._args)
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py', line 545
# [Warning] [omni.isaac.kit]   await self.process_one()
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py', line 534
# [Warning] [omni.isaac.kit]   await dispatch(*args)
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py', line 437
# [Warning] [omni.isaac.kit]   await result
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py', line 362
# [Warning] [omni.isaac.kit]   await super().execute_request(stream, ident, parent)
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py', line 778
# [Warning] [omni.isaac.kit]   reply_content = await reply_content
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py', line 449
# [Warning] [omni.isaac.kit]   res = shell.run_cell(
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/liStarting kit application with the following args:  ['/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/exts', '--ext-folder', '/home/ubuntu/Omniverse/library/isaac-sim-4.2.0/apps', '--/physics/cudaDevice=0', '--portable', '--no-window', '--/app/window/hideUi=1']
# Passing the following args to the base kit application:  ['-f', '/home/ubuntu/.local/share/jupyter/runtime/kernel-19234253-1b39-4530-b942-4df87c72ed06.json']
# b/python3.10/site-packages/ipykernel/zmqshell.py', line 549
# [Warning] [omni.isaac.kit]   return super().run_cell(*args, **kwargs)
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py', line 3075
# [Warning] [omni.isaac.kit]   result = self._run_cell(
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py', line 3130
# [Warning] [omni.isaac.kit]   result = runner(coro)
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py', line 128
# [Warning] [omni.isaac.kit]   coro.send(None)
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py', line 3334
# [Warning] [omni.isaac.kit]   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# [Warning] [omni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py', line 3517
# [Warning] [omni.isaac.kit]   if await self.run_code(code, result, async_=asy):
# ni.isaac.kit] File '/home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py', line 3577
# [Warning] [omni.isaac.kit]   exec(code_obj, self.user_global_ns, self.user_ns)
# [Warning] [omni.isaac.kit] File '/tmp/ipykernel_417110/1673268652.py', line 4
# [Warning] [omni.isaac.kit]   from omni.isaac.kit import SimulationApp
# [Warning] [omni.isaac.kit]
# [Warning] [omni.isaac.kit] Please import 'isaacsim' before importing the 'omni.isaac.kit' extension...
# [Warning] [omni.isaac.kit]   >>> import isaacsim
# [Warning] [omni.isaac.kit]   >>> from omni.isaac.kit import SimulationApp
# [Warning] [omni.isaac.kit]
# [Warning] [omni.isaac.kit] or get the 'SimulationApp' class directly from the 'isaacsim' module
# [Warning] [omni.isaac.kit]   >>> from isaacsim import SimulationApp
# [Warning] [omni.isaac.kit]
# [Warning] [omni.isaac.kit] ===========================================================================
# [Warning] [omni.isaac.kit]
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Info] [carb] Logging to file: /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/logs/Kit/Isaac-Sim/4.2/kit_20250304_175733.log
# 2025-03-04 17:57:33 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.129s] [ext: omni.blobkey-1.1.2] startup
# [0.130s] [ext: omni.kit.async_engine-0.0.1] startup
# [1.069s] [ext: omni.stats-1.0.1] startup
# [1.071s] [ext: omni.datastore-0.0.0] startup
# [1.078s] [ext: omni.client-1.2.0] startup
# [1.121s] [ext: omni.ujitso.default-1.0.0] startup
# [1.123s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [1.128s] [ext: omni.hsscclient-1.1.1] startup
# [1.128s] [ext: omni.assets.plugins-0.0.0] startup
# [1.131s] [ext: omni.gpu_foundation-0.0.0] startup
# [1.143s] [ext: carb.windowing.plugins-1.0.0] startup
# [1.158s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 560.35.03     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA A10G                      | Yes: 0 |     | 23028   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2237      | c1657f22.. |
# |     |                                  |        |     |            | 0         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-1015-aws
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: AMD EPYC 7R32 | Cores: 8 | Logical: 16
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 63611 | Free Memory: 42517
# | Total Page/Swap (MB): 0 | Free Page/Swap: 0
# |---------------------------------------------------------------------------------------------|
# 2025-03-04 17:57:35 [2,031ms] [Warning] [gpu.foundation.plugin] ECC is enabled on physical device 0
# [2.362s] [ext: omni.kit.pipapi-0.0.0] startup
# [2.364s] [ext: omni.kit.pip_archive-0.0.0] startup
# [2.365s] [ext: omni.pip.compute-1.4.0] startup
# [2.365s] [ext: omni.pip.cloud-1.1.3] startup
# [2.368s] [ext: omni.isaac.core_archive-2.3.0] startup
# [2.369s] [ext: omni.materialx.libs-1.0.4] startup
# [2.383s] [ext: omni.isaac.ml_archive-2.0.1] startup
# [2.383s] [ext: omni.kit.telemetry-0.5.0] startup
# [2.445s] [ext: omni.usd.config-1.0.4] startup
# [2.457s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [2.459s] [ext: omni.usd.libs-1.0.1] startup
# [2.606s] [ext: omni.iray.libs-0.0.0] startup
# ni.mdl.neuraylib-0.2.8] startup
# [2.618s] [ext: omni.mdl-55.0.1] startup
# [2.699s] [ext: omni.kit.usd.mdl-1.0.1] startup
# [3.144s] [ext: omni.kit.loop-isaac-1.2.0] startup
# [3.149s] [ext: omni.kit.test-1.1.0] startup
# [3.274s] [ext: omni.appwindow-1.1.8] startup
# [3.281s] [ext: omni.kit.renderer.core-1.0.2] startup
# [3.328s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [3.331s] [ext: omni.kit.renderer.imgui-1.0.1] startup
# [3.441s] [ext: omni.ui-2.25.22] startup
# [3.457s] [ext: omni.kit.mainwindow-1.0.3] startup
# [3.459s] [ext: carb.audio-0.1.0] startup
# [3.466s] [ext: omni.uiaudio-1.0.0] startup
# [3.468s] [ext: omni.kit.uiapp-0.0.0] startup
# [3.468s] [ext: omni.usd.schema.isaac-2.1.0] startup
# [3.482s] [ext: omni.usd.schema.audio-0.0.0] startup
# [3.487s] [ext: omni.usd.schema.anim-0.0.0] startup
# [3.523s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [3.527s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [3.531s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [3.542s] [ext: omni.anim.navigation.schema-106.1.0] startup
# [3.547s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [3.549s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [3.557s] [ext: omni.anim.graph.schema-106.1.0] startup
# [3.568s] [ext: omni.usd.schema.physx-106.1.9] startup
# [3.619s] [ext: omni.usd.schema.forcefield-106.1.9] startup
# [3.628s] [ext: omni.graph.exec-0.9.4] startup
# [3.630s] [ext: omni.kit.usd_undo-0.1.8] startup
# [3.630s] [ext: omni.kit.actions.core-1.0.0] startup
# [3.633s] [ext: omni.kit.exec.core-0.13.4] startup
# [3.638s] [ext: omni.usd_resolver-1.0.0] startup
# [3.644s] [ext: omni.kit.commands-1.4.9] startup
# [3.651s] [ext: omni.activity.core-1.0.1] startup
# [3.654s] [ext: omni.usd.core-1.4.1] startup
# [3.658s] [ext: omni.resourcemonitor-105.0.1] startup
# [3.661s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [3.668s] [ext: omni.timeline-1.0.10] startup
# [3.671s] [ext: omni.kit.widget.nucleus_connector-1.1.9] startup
# [3.674s] [ext: usdrt.scenegraph-7.5.0] startup
# [3.750s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [3.752s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [3.773s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [3.780s] [ext: omni.usd-1.12.2] startup
# [3.841s] [ext: omni.kit.menu.core-1.0.4] startup
# [3.842s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [3.843s] [ext: omni.kit.property.adapter.core-1.0.1] startup
# [3.849s] [ext: omni.kit.menu.utils-1.5.27] startup
# [3.861s] [ext: omni.kit.clipboard-1.0.4] startup
# [3.862s] [ext: omni.kit.collaboration.channel_manager-1.0.12] startup
# [3.864s] [ext: omni.kit.property.adapter.usd-1.0.1] startup
# [3.865s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [3.870s] [ext: omni.kit.widget.graph-1.12.15] startup
# [3.877s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [3.880s] [ext: omni.kit.widget.filter-1.1.4] startup
# [3.882s] [ext: omni.kit.property.adapter.fabric-1.0.1] startup
# [3.884s] [ext: omni.ui_query-1.1.4] startup
# [3.885s] [ext: omni.kit.window.extensions-1.4.11] startup
# [3.897s] [ext: omni.kit.usd.layers-2.1.36] startup
# [3.914s] [ext: omni.kit.widget.context_menu-1.2.2] startup
# [3.916s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [3.918s] [ext: omni.kit.notification_manager-1.0.9] startup
# [3.921s] [ext: omni.kit.hotkeys.core-1.3.5] startup
# [3.923s] [ext: omni.kit.context_menu-1.8.1] startup
# [3.926s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [3.927s] [ext: omni.kit.helper.file_utils-0.1.8] startup
# [3.930s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [3.932s] [ext: omni.kit.widget.filebrowser-2.10.51] startup
# [3.940s] [ext: omni.kit.search_core-1.0.5] startup
# [3.941s] [ext: omni.kit.widget.path_field-2.0.10] startup
# [3.943s] [ext: omni.ui.scene-1.10.3] startup
# [3.953s] [ext: omni.kit.widget.search_delegate-1.0.5] startup
# [3.955s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [3.956s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [3.957s] [ext: omni.volume-0.5.0] startup
# [3.963s] [ext: omni.kit.window.filepicker-2.10.40] startup
# [3.980s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [3.982s] [ext: omni.kit.window.file_exporter-1.0.30] startup
# [3.986s] [ext: omni.ujitso.client-0.0.0] startup
# [3.987s] [ext: omni.kit.widget.stage-2.11.2] startup
# [4.004s] [ext: omni.kit.widget.live_session_management.ui-1.0.1] startup
# [4.007s] [ext: omni.kit.collaboration.presence_layer-1.0.9] startup
# [4.011s] [ext: omni.hydra.rtx-1.0.0] startup
# [4.039s] [ext: omni.inspect-1.0.1] startup
# [4.042s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [4.044s] [ext: omni.kit.window.file_importer-1.1.12] startup
# [4.045s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [4.046s] [ext: omni.kit.widget.settings-1.2.2] startup
# [4.050s] [ext: omni.kit.window.file-1.3.54] startup
# [4.055s] [ext: omni.kit.window.drop_support-1.0.3] startup
# [4.056s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [4.057s] [ext: omni.kit.window.preferences-1.6.0] startup
# [4.073s] [ext: omni.kit.window.content_browser-2.9.18] startup
# [4.104s] [ext: omni.kit.widget.live_session_management-1.2.20] startup
# [4.108s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [4.111s] [ext: omni.kit.hydra_texture-1.3.9] startup
# [4.118s] [ext: omni.kit.viewport.legacy_gizmos-1.1.0] startup
# [4.122s] [ext: omni.kit.raycast.query-1.0.5] startup
# [4.131s] [ext: omni.kit.material.library-1.5.6] startup
# [4.143s] [ext: omni.kit.widget.viewport-106.1.0] startup
# [4.149s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [4.150s] [ext: omni.hydra.engine.stats-1.0.2] startup
# [4.155s] [ext: omni.kit.widget.highlight_label-1.0.2] startup
# [4.156s] [ext: omni.kit.viewport.window-107.0.6] startup
# [4.194s] [ext: omni.kit.window.property-1.11.3] startup
# [4.198s] [ext: omni.graph.core-2.179.2] startup
# [4.202s] [ext: omni.graph.tools-1.79.0] startup
# [4.244s] [ext: omni.kit.viewport.utility-1.0.17] startup
# [4.245s] [ext: omni.kit.property.usd-4.2.8] startup
# [4.262s] [ext: omni.debugdraw-0.1.3] startup
# [4.269s] [ext: omni.graph-1.140.0] startup
# [4.456s] [ext: omni.graph.ui-1.70.2] startup
# [4.492s] [ext: omni.kvdb-106.1.9] startup
# [4.500s] [ext: omni.graph.image.core-0.4.5] startup
# [4.503s] [ext: omni.localcache-106.1.9] startup
# [4.506s] [ext: omni.graph.image.nodes-1.1.0] startup
# [4.511s] [ext: omni.usdphysics-106.1.9] startup
# [4.518s] [ext: omni.physx.foundation-106.1.9] startup
# [4.523s] [ext: omni.convexdecomposition-106.1.9] startup
# [4.533s] [ext: omni.graph.nodes-1.146.1] startup
# [4.553s] [ext: omni.physx.cooking-106.1.9] startup
# [4.577s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [4.583s] [ext: omni.physx-106.1.9] startup
# [4.603s] [ext: omni.kit.stage_templates-1.2.5] startup
# [4.609s] [ext: omni.isaac.version-1.1.0] startup
# [4.610s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [4.614s] [ext: omni.isaac.nucleus-0.3.1] startup
# [4.616s] [ext: omni.physics.tensors-106.1.9] startup
# [4.629s] [ext: omni.physx.stageupdate-106.1.9] startup
# [4.634s] [ext: omni.graph.action_core-1.1.6] startup
# [4.640s] [ext: omni.warp.core-1.2.1] startup
# [4.831s] [ext: omni.physx.tensors-106.1.9] startup
# [4.841s] [ext: omni.graph.scriptnode-1.20.1] startup
# [4.843s] [ext: omni.kit.manipulator.viewport-107.0.0] startup
# [4.849s] [ext: omni.graph.action_nodes-1.24.0] startup
# [4.865s] [ext: omni.kit.ui_test-1.3.2] startup
# [4.877s] [ext: omni.isaac.core-3.19.5] startup
# [7.437s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [7.450s] [ext: omni.graph.action-1.102.1] startup
# [7.453s] [ext: omni.kit.window.cursor-1.1.2] startup
# [7.460s] [ext: omni.isaac.ui-0.16.0] startup
# [7.477s] [ext: omni.kit.viewport.menubar.core-106.1.0] startup
# [7.516s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [7.519s] [ext: omni.syntheticdata-0.6.9] startup
# [7.578s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [7.583s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [7.596s] [ext: omni.kit.numpy.common-0.1.2] startup
# [7.603s] [ext: omni.warp-1.2.1] startup
# [7.630s] [ext: omni.kit.window.material_graph-1.8.18] startup
# [7.735s] [ext: omni.isaac.dynamic_control-1.3.8] startup
# [7.778s] [ext: omni.replicator.core-1.11.20] startup
# Warp 1.2.1 initialized:800ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registere
#    CUDA Toolkit 11.8, Driver 12.6
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA A10G" (22 GiB, sm_86, mempool enabled)
#    Kernel cache:
#      /home/ubuntu/.cache/warp/1.2.1
# d, overwriting annotator template
# [8.094s] [ext: omni.isaac.lula-3.0.1] startup
# [8.110s] [ext: omni.isaac.surface_gripper-1.0.1] startup
# [8.119s] [ext: omni.isaac.core_nodes-1.16.3] startup
# [8.180s] [ext: omni.isaac.motion_generation-7.1.0] startup
# [8.250s] [ext: omni.isaac.manipulators-2.1.0] startup
# [8.285s] [ext: omni.isaac.franka-0.4.1] startup
# [8.319s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [8.345s] [ext: omni.kit.graph.delegate.modern-1.10.6] startup
# [8.380s] [ext: omni.isaac.cortex-0.3.9] startup
# [8.391s] [ext: omni.graph.window.core-1.113.1] startup
# [8.464s] [ext: omni.isaac.wheeled_robots-2.3.3] startup
# [8.485s] [ext: omni.isaac.cortex.sample_behaviors-1.0.6] startup
# [8.491s] [ext: omni.graph.window.generic-1.26.0] startup
# [8.536s] [ext: omni.isaac.menu-0.7.3] startup
# [8.565s] [ext: omni.kit.widget.live-2.1.8] startup
# [8.578s] [ext: omni.kit.actions.window-1.1.1] startup
# [8.598s] [ext: omni.kit.widget.cache_indicator-2.0.10] startup
# 2025-03-04 17:57:42 [8,702ms] [Warning] [omni.kit.widget.cache_indicator.cache_state_menu] Unable to detect Omniverse Cache Server. Consider installing it for better IO performance.
# [8.773s] [ext: omni.kit.hotkeys.window-1.4.5] startup
# [8.791s] [ext: omni.kit.ui.actions-1.0.2] startup
# [8.805s] [ext: omni.kit.widget.stage_icons-1.0.5] startup
# [8.808s] [ext: omni.kit.menu.common-1.1.7] startup
# [8.810s] [ext: omni.kit.selection-0.1.4] startup
# [8.813s] [ext: omni.isaac.kit-1.13.2] startup
# [8.814s] [ext: omni.isaac.block_world-1.0.0] startup
# [8.818s] [ext: omni.kit.window.stage-2.5.10] startup
# [8.827s] [ext: omni.isaac.debug_draw-1.1.0] startup
# [8.833s] [ext: omni.kit.menu.edit-1.1.24] startup
# [8.845s] [ext: omni.kit.menu.file-1.1.14] startup
# [8.848s] [ext: omni.kit.profiler.window-2.2.3] startup
# [8.860s] [ext: omni.kit.menu.stage-1.2.5] startup
# [8.863s] [ext: omni.isaac.occupancy_map-1.0.3] startup
# [8.872s] [ext: omni.importer.mjcf-1.1.1] startup
# [8.884s] [ext: omni.graph.window.action-1.28.0] startup
# [8.898s] [ext: omni.kit.property.camera-1.0.8] startup
# [8.903s] [ext: omni.kit.property.light-1.0.10] startup
# [8.910s] [ext: omni.kit.property.geometry-1.3.1] startup
# [8.915s] [ext: omni.hydra.scene_api-0.1.2] startup
# [8.923s] [ext: omni.kit.property.audio-1.0.14] startup
# [8.928s] [ext: omni.kit.property.render-1.1.2] startup
# [8.932s] [ext: omni.kit.property.transform-1.5.9] startup
# [8.938s] [ext: omni.kit.property.material-1.10.8] startup
# [8.948s] [ext: omni.kit.widget.layers-1.8.0] startup
# [8.970s] [ext: omni.kit.property.isaac-0.2.3] startup
# [8.972s] [ext: omni.kit.property.bundle-1.3.1] startup
# [8.976s] [ext: omni.sensors.nv.common-1.2.2-isaac-1] startup
# [8.995s] [ext: omni.kit.property.layer-1.1.8] startup
# [8.998s] [ext: omni.kit.stage_column.payload-2.0.0] startup
# [9.002s] [ext: omni.isaac.scene_blox-0.1.2] startup
# [9.004s] [ext: omni.sensors.nv.materials-1.2.1-isaac-1] startup
# [9.009s] [ext: omni.sensors.nv.wpm-1.2.1-isaac-1] startup
# [9.011s] [ext: omni.kit.viewport.actions-106.0.2] startup
# [9.019s] [ext: omni.sensors.nv.lidar-1.2.2-isaac-1] startup
# [9.028s] [ext: omni.sensors.nv.radar-1.2.1-isaac-1] startup
# [9.037s] [ext: omni.kit.viewport.menubar.display-107.0.2] startup
# [9.041s] [ext: omni.kit.manipulator.transform-104.7.4] startup
# [9.046s] [ext: omni.kit.widget.toolbar-1.7.2] startup
# [9.059s] [ext: omni.sensors.tiled-0.0.6] startup
# [9.063s] [ext: omni.sensors.nv.ids-1.1.0-isaac-1] startup
# [9.070s] [ext: omni.isaac.range_sensor-3.1.2] startup
# [9.092s] [ext: omni.usdphysics.ui-106.1.9] startup
# [9.136s] [ext: omni.physx.commands-106.1.9] startup
# [9.142s] [ext: omni.kit.manipulator.tool.snap-1.5.11] startup
# [9.151s] [ext: omni.isaac.sensor-12.9.1] startup
# [9.282s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [9.289s] [ext: omni.physx.ui-106.1.9] startup
# [9.374s] [ext: omni.isaac.quadruped-2.0.1] startup
# [9.390s] [ext: omni.kit.viewport.manipulator.transform-107.0.2] startup
# [9.397s] [ext: omni.physx.demos-106.1.9] startup
# [9.437s] [ext: omni.kit.property.physx-106.1.9] startup
# [9.575s] [ext: omni.kit.widget.calendar-1.0.8] startup
# or.prim.core-107.0.4] startupulat
# [9.593s] [ext: omni.fabric.commands-1.1.5] startup
# [9.599s] [ext: omni.physx.vehicle-106.1.9] startup
# [9.632s] [ext: omni.kit.widget.extended_searchfield-1.0.28] startup
# [9.649s] [ext: omni.kit.manipulator.prim.fabric-107.0.3] startup
# [9.654s] [ext: omni.kit.manipulator.prim.usd-107.0.2] startup
# [9.657s] [ext: omni.kit.widget.timeline-105.0.1] startup
# [9.662s] [ext: omni.kit.window.commands-0.2.6] startup
# [9.666s] [ext: omni.physx.camera-106.1.9] startup
# [9.687s] [ext: omni.kit.manipulator.camera-105.0.5] startup
# [9.695s] [ext: omni.kit.viewport.menubar.camera-107.0.2] startup
# [9.704s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [9.705s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [9.707s] [ext: omni.kit.window.toolbar-1.6.1] startup
# [9.712s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [9.715s] [ext: omni.kit.viewport.menubar.render-106.1.1] startup
# [9.720s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [9.728s] [ext: omni.physx.cct-106.1.9] startup
# [9.753s] [ext: omni.physx.graph-106.1.9] startup
# [9.802s] [ext: omni.physx.supportui-106.1.9] startup
# [9.838s] [ext: omni.physx.telemetry-106.1.9] startup
# [9.844s] [ext: omni.graph.ui_nodes-1.26.0] startup
# [9.854s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [9.856s] [ext: omni.isaac.universal_robots-0.3.5] startup
# [9.863s] [ext: omni.kit.window.console-0.2.13] startup
# [9.884s] [ext: omni.kit.window.script_editor-1.7.6] startup
# [9.893s] [ext: omni.kit.menu.create-1.0.16] startup
# [9.905s] [ext: omni.graph.bundle.action-2.4.1] startup
# [9.915s] [ext: omni.physx.bundle-106.1.9] startup
# [9.917s] [ext: omni.rtx.window.settings-0.6.17] startup
# [9.936s] [ext: omni.kit.window.status_bar-0.1.7] startup
# [9.950s] [ext: omni.kit.window.title-1.1.5] startup
# [9.953s] [ext: omni.replicator.isaac-1.15.2] startup
# [10.000s] [ext: omni.replicator.replicator_yaml-2.0.6] startup
# [10.047s] [ext: omni.rtx.settings.core-0.6.3] startup
# [10.072s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [10.088s] [ext: semantics.schema.editor-0.3.8] startup
# [10.107s] [ext: semantics.schema.property-1.0.4] startup
# [10.110s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [10.112s] [ext: omni.isaac.utils-1.0.1] startup
# [10.118s] [ext: omni.isaac.cloner-0.8.1] startup
# [10.126s] [ext: omni.importer.urdf-1.14.1] startup
# [10.227s] [ext: omni.kit.window.stats-0.1.6] startup
# [10.229s] [ext: omni.isaac.sim.python-4.2.0] startup
# [10.231s] Simulation App Starting
# 2025-03-04 17:57:44 [10,265ms] [Warning] [omni.kvdb.plugin] Disabling key-value database because another kit process is locking it
# Saving a temp livesync stage at  omniverse://localhost/Users/ubuntu/test.usd  ...Done.
# 2025-03-04 17:57:47 [13,285ms] [Error] [gpu.foundation.plugin] Failed to read texture file ./textures/color_121212.hdr or file is empty
# 2025-03-04 17:57:47 [13,286ms] [Error] [rtx.scenedb.plugin] Failed to upload DomeLight texture ./textures/color_121212.hdr
# [13.519s] app ready

# %%
import carb
from omni.physx import get_physx_scene_query_interface  # for raycasting e.g raycast_closest()
from omni.isaac.core import World
from omni.isaac.core.objects import DynamicCuboid, DynamicSphere, DynamicCone
from omni.timeline import get_timeline_interface
from omni.isaac.core.utils.stage import get_current_stage
import omni.isaac.core.utils.prims as prims_utils
from omni.usd import get_prim_at_path
import omni.isaac.core.utils.mesh as mesh_utils


import matplotlib.pyplot as plt
from pprint import pprint
import numpy as np
from scipy.interpolate import PchipInterpolator
import typing
from pxr import Usd, UsdGeom, Gf

# %% [markdown]
# # Setup Simple Scene

# %%
world = World(stage_units_in_meters=1.0)
stage = get_current_stage()
world.clear()
# world.scene.add_default_ground_plane()
# A render/ step or an update call is needed to reflect the changes to the opened USD in Isaac Sim GUI
#  Note: avoid pressing play/ pause or stop in the GUI in this workflow.
world.render()

# Create the Sun
sun = prims_utils.create_prim(
    "/World/Sun",
    "SphereLight",
    position=[1.0, 1.0, 100.0],
    attributes={
        "inputs:radius": 1,
        "inputs:intensity": 5e3,
        "inputs:color": (1.0, 1.0, 1.0)
    }
)
world.render()

# %%
# Load a USD prepared with the meshes of ground + solar panel + two supports

# IMPORTANT: First time: copy paste the usd from the github repository to the nucleus server
# from: <path to the repository>/jaops-sim/scenes/assets/simplified_surface_solar_panel.usd
# to: omniverse://localhost/Users/<your username>/simplified_surface_solar_panel.usd
# (you can copy paste within the IsaacSim Content Window)


usd_path = f"omniverse://localhost/Users/ubuntu/moon_environnement.usdc"#
prim_path = "/World/Lunar_Base"

# create the prim
prim = prims_utils.create_prim(prim_path=prim_path, usd_path=usd_path)
world.render()

timeline = get_timeline_interface()
timeline.play()
for _ in range(2):
    simulation_app.update()
timeline.pause()
# Out:
# [15.027s] Simulation App Startup Complete
# 2025-03-04 17:57:50 [16,268ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:57:50 [16,268ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:57:50 [16,268ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:57:50 [16,268ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:57:50 [16,268ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:57:50 [16,268ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:57:50 [16,476ms] [Warning] [omni.fabric.plugin] removePath called on non-existent path /World/Lunar_Base/Panel
# 2025-03-04 17:57:50 [17,085ms] [Error] [rtx.scenedb.plugin] Failed to upload DomeLight texture ./textures/color_121212.hdr

# %% [markdown]
# # Classes

# %%
from Lunar_Dust import LunarDust 
from Panel_Class import Panel

# %% [markdown]
# # Tests

# %%
# Rover prim introduction

usd_path = f"omniverse://localhost/Users/ubuntu/Rover_e_panneau_orig.usd"#solar_panel_final.usdc"
rover_prim_path = prim_path + "/Rover"

rover = prims_utils.create_prim(prim_path=rover_prim_path, usd_path=usd_path, scale=[20,20,20], position = [20, -40, 20])


world.render()
# Out:
# 2025-03-04 17:57:51 [17,163ms] [Warning] [omni.usd] Coding Error: in AddXformOp at line 224 of /builds/omniverse/usd-ci/USD/pxr/usd/usdGeom/xformable.cpp -- Unable to add xform op of type TypeTranslate and precision PrecisionFloat on prim at path </World/Lunar_Base/Moon_terrain/WC_Terrain_0_0/WC_Terrain_mesh>. opSuffix=, isInverseOp=0
#
# 2025-03-04 17:57:51 [17,163ms] [Warning] [omni.usd] Coding Error: in AddXformOp at line 224 of /builds/omniverse/usd-ci/USD/pxr/usd/usdGeom/xformable.cpp -- Unable to add xform op of type TypeOrient and precision PrecisionFloat on prim at path </World/Lunar_Base/Moon_terrain/WC_Terrain_0_0/WC_Terrain_mesh>. opSuffix=, isInverseOp=0
#
# 2025-03-04 17:57:51 [17,163ms] [Warning] [omni.usd] Coding Error: in AddXformOp at line 224 of /builds/omniverse/usd-ci/USD/pxr/usd/usdGeom/xformable.cpp -- Unable to add xform op of type TypeScale and precision PrecisionFloat on prim at path </World/Lunar_Base/Moon_terrain/WC_Terrain_0_0/WC_Terrain_mesh>. opSuffix=, isInverseOp=0
#
# 2025-03-04 17:57:51 [17,170ms] [Warning] [omni.hydra.scene_delegate.plugin] cannot find xform op xformOp:orient for /World/Lunar_Base/Moon_terrain/WC_Terrain_0_0/WC_Terrain_mesh
#
# 2025-03-04 17:57:51 [17,170ms] [Warning] [omni.hydra.scene_delegate.plugin] cannot find xform op xformOp:translate for /World/Lunar_Base/Moon_terrain/WC_Terrain_0_0/WC_Terrain_mesh
#
# 2025-03-04 17:57:51 [17,364ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2Context'
# 2025-03-04 17:57:51 [17,364ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2SubscribeTwist'
# 2025-03-04 17:57:51 [17,370ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2PublishTransformTree'
# 2025-03-04 17:57:51 [17,370ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2PublishOdometry'
# 2025-03-04 17:57:51 [17,370ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2PublishRawTransformTree'
# 2025-03-04 17:57:51 [17,370ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2Context'
# 2025-03-04 17:57:51 [17,370ms] [Warning] [omni.timeline.plugin] Deprecated: direct use of ITimeline callbacks is deprecated. Use ITimeline::getTimeline (Python: omni.timeline.get_timeline_interface) instead.
# 2025-03-04 17:57:51 [17,371ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2Context'
# 2025-03-04 17:57:51 [17,371ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2PublishClock'
# 2025-03-04 17:57:51 [17,372ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2Context'
# 2025-03-04 17:57:51 [17,372ms] [Warning] [omni.graph.core.plugin] Could not find node type interface for 'omni.isaac.ros2_bridge.ROS2PublishPointCloud'
# 2025-03-04 17:57:51 [17,381ms] [Warning] [omni.usd] Warning (secondary thread): in _ReportErrors at line 2890 of /builds/omniverse/usd-ci/USD/pxr/usd/usd/stage.cpp -- In </World/Lunar_Base/Rover/d455/RSD455/Visual/USB_C.material:binding>: The relationship target </D455/INTEL_REALSENSE_D455_CAD_EXTERN_ASM/MD0645501_ASM_12_ASM/AS0605401_ASM_4_ASM/_0137062C_1_ASM_2_ASM/_0137062C_1_1_1/Looks/Tropical_Blue> from </Root/RSD455/Visual/USB_C.material:binding> in layer @omniverse://localhost/NVIDIA/Assets/Isaac/4.0/Isaac/Sensors/Intel/RealSense/rsd455.usd@ refers to a path outside the scope of the reference from </husky_robot/d455>.  Ignoring. (getting targets for relationship </World/Lunar_Base/Rover/d455/RSD455/Visual/USB_C.material:binding> on stage @omniverse://localhost/Users/ubuntu/test.usd@ <0x11b2fbf0>)
#
# 2025-03-04 17:57:51 [17,396ms] [Warning] [omni.hydra] Fisheye equidistant projection is deprecated and will be removed in the next release.
# 2025-03-04 17:57:54 [20,342ms] [Warning] [omni.usd] Warning (secondary thread): in _Re

# %%
# Definition of paths and starting of classes

panel_prim_path = rover_prim_path + "/solo_solar_pannel"

#panel = prims_utils.get_prim_at_path(panel_prim_path)

dust_model = LunarDust(world)
dust_model.reduction_altitude = 26.5  ####### for test purposes

panel_path = panel_prim_path + "/cilindro_est_centro/pannello_base"
panel_color_path = panel_prim_path + "/_materials/Material/Principled_BSDF" 
panel = prim.GetPrimAtPath(panel_path)

dust_model.update(0, panel)
dust_model.update_color(panel_color_path)
original_color = dust_model.original_color
# Out:
# DUST COVERAGE LIMITED BY DUST SIZE
# Max surface coverage for  4e-05  m dust:  0.10867968750000001
# Time Passed:  0.0  minutes
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  0.0 %

# %%
# TEST: manual time passing; the lunar dust will accumulate during time 
# up until the maximum coverage value specified in the class definition

import time

dust_model.reset_accumulation()
dust_model.set_color(panel_color_path, original_color)



i=0
coverage_points = []
time_points = []
while i < 200:
    
    dust_model.update(i*10000000, panel)
    dust_model.update_color(panel_color_path)

    time.sleep(0.8)
    coverage_points.append(dust_model.coverage * 100)
    time_points.append(i*100)
    
    i+=1

    
print(coverage_points)
plt.figure()
plt.plot(time_points, coverage_points)
plt.grid(True)
plt.xlabel("Seconds")
plt.ylabel("Covered surface (%)")
plt.title("Covered surface by time")
plt.show()
# Out:
# Time Passed:  0.0  minutes
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  0.0 %
#
# Time Passed:  115.74  days
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  1.0209580048360598 %
#
# Time Passed:  0.63  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  2.0419160096721196 %
#
# Time Passed:  0.95  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  3.0628740145081794 %
#
# Time Passed:  1.27  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  4.083832019344239 %
#
# Time Passed:  1.59  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  5.104790024180299 %
#
# Time Passed:  1.9  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  6.125748029016358 %
#
# Time Passed:  2.22  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  7.146706033852418 %
#
# Time Passed:  2.54  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  8.167664038688478 %
#
# Time Passed:  2.85  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  9.18862204352454 %
#
# Time Passed:  3.17  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  10.209580048360598 %
#
# Time Passed:  3.49  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  10.867968750000001 %
#
# Time Passed:  3.81  years
# Altitude:  0.92  m
# Taux de deposition:  128.79  micrograms/cm^2*y
# Covered surface by dust:  10.867968750000001 %
# KeyboardInterrupt

# %% [markdown]
# # Tests with solar panel

# %%
prims_utils.delete_prim(rover_prim_path)
world.render()

# %%
def adjust_light(stage, position, intensity=3e9, radius=0.01):
    """
    Adjusts the properties of the first SphereLight found in the given stage.

    Parameters:
    stage (Usd.Stage): The stage containing the lights.
    position (tuple): A tuple representing the new position (x, y, z) of the light.
    intensity (float, optional): The new intensity of the light. Default is 3e9.
    radius (float, optional): The new radius of the light. Default is 0.01.

    Returns:
        None
    """
    lights = []
    for prim in stage.Traverse():
        if prim.GetTypeName() == "SphereLight":
            lights.append(prim)
    if lights:
        light = lights[0]
        light_path = light.GetPath()
        # Adjust position
        translate_attr = stage.GetPrimAtPath(light_path).GetAttribute(
            "xformOp:translate"
        )
        translate_attr.Set(position)
        # Adjust intensity
        intensity_attr = stage.GetPrimAtPath(light_path).GetAttribute(
            "inputs:intensity"
        )
        intensity_attr.Set(intensity)
        # Adjust radius
        radius_attr = stage.GetPrimAtPath(light_path).GetAttribute("inputs:radius")
        radius_attr.Set(0.01)

# %%
usd_path = f"omniverse://localhost/Users/ubuntu/solar_panel_final_turned.usd"
panel_prim_path = prim_path + "/Panel"

panel_structure = prims_utils.create_prim(prim_path=panel_prim_path, usd_path=usd_path, scale=[20,20,20], position = [20, -40, 15])
world.render()

panel = prims_utils.get_prim_at_path(panel_prim_path)

dust_model = LunarDust(world)

panel_path = panel_prim_path + "/cilindro_est_centro/pannello_base"
panel_color_path = panel_prim_path + "/_materials/Material/Principled_BSDF" 
panel = prim.GetPrimAtPath(panel_path)

dust_model.update(0, panel)
dust_model.update_color(panel_color_path)
original_color = dust_model.original_color
# Out:
# DUST COVERAGE LIMITED BY DUST SIZE
# Max surface coverage for  4e-05  m dust:  0.10867968750000001
# Time Passed:  0.0  minutes
# Altitude:  28.5  m
# Taux de deposition:  7.86  micrograms/cm^2*y
# Covered surface by dust:  0.0 %

# %%
# PANEL CLASS TEST WITH DIFFERENT ANGLES

import omni.isaac.core.utils.rotations as rotations_utils

panel_prim_path = prim_path + "/Panel"

dust_model.reduction_altitude = 26.5
panel_test = Panel(panel_prim_path)
panel_test.display_state()

N = 100
panel_angles = np.zeros((N, 3)) 
panel_angles[:,0] = np.linspace(-50, 50, num=N)

sun_angles = np.zeros((N, 3))
sun_angles[:,0] = 3 * np.cos(np.linspace(0, 3.14, num=N))
sun_angles[:,1] = 3 * np.sin(np.linspace(0, 3.14, num=N))
sun_angles[:,2] = 50 + np.linspace(.05, 7.5, num=N)

battery_charge = []
power_produced = []
for p,s in zip(panel_angles, sun_angles):
    panel_test.set_panel_orientation_euler(p, degrees = True)
    adjust_light(stage, tuple(s))
    
    timeline.play()
    for _ in range(2):
        simulation_app.update()
    timeline.pause()

    panel_test.update(stage, 100*i) ### CHANGED
    
    #panel_test.update_power_produced(stage)
    #print(panel_test.power_produced)
    #panel_test.update_state(100)
    battery_charge.append(panel_test.current_storage)
    power_produced.append(panel_test.power_produced)
    
    panel_test.display_state()
    world.render()
    i+=1 ### CHANGED
# Out:
# Battery is at 0.0%, actual production (W) : 0, actual consumption (W): 10 | current_storage (Wh) : 0
# g> in layer @omniverse://localhost/NVIDIA/Assets/Isaac/4.0/Isaac/Sensors/Intel/RealSense/rsd455.usd@ refers to a path outside the scope of the reference from </husky_robot/d455>.  Ignoring. (getting targets for relationship </World/Lunar_Base/Rover/d455/RSD455/Visual/USB_C.material:binding> on stage @omniverse://localhost/Users/ubuntu/test.usd@ <0x1231b120>)
#
# 2025-03-04 17:42:18 [19,761ms] [Warning] [omni.usd] Warning: in _ReportErrors at line 2890 of /builds/omniverse/usd-ci/USD/pxr/usd/usd/stage.cpp -- In </World/Lunar_Base/Rover/d455/RSD455/Visual/USB_C.material:binding>: The relationship target </D455/INTEL_REALSENSE_D455_CAD_EXTERN_ASM/MD0645501_ASM_12_ASM/AS0605401_ASM_4_ASM/_0137062C_1_ASM_2_ASM/_0137062C_1_1_1/Looks/Tropical_Blue> from </Root/RSD455/Visual/USB_C.material:binding> in layer @omniverse://localhost/NVIDIA/Assets/Isaac/4.0/Isaac/Sensors/Intel/RealSense/rsd455.usd@ refers to a path outside the scope of the reference from </husky_robot/d455>.  Ignoring. (getting targets for relationship </World/Lunar_Base/Rover/d455/RSD455/Visual/USB_C.material:binding> on stage @omniverse://localhost/Users/ubuntu/test.usd@ <0x1231b120>)
#
# 2025-03-04 17:47:44 [345,414ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,414ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,414ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,414ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,414ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,415ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,415ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,415ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,415ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,415ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,415ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,415ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:47:44 [345,415ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:50:04 [485,234ms] [Warning] [omni.usd] Coding Error: in AddXformOp at line 190 of /builds/omniverse/usd-ci/USD/pxr/usd/usdGeom/xformable.cpp -- The xformOp 'xformOp:translate' already exists in xformOpOrder [[xformOp:translate, xformOp:rotateXYZ, xformOp:scale]].
#
# 2025-03-04 17:50:04 [485,234ms] [Warning] [omni.usd] Coding Error: in AddXformOp at line 224 of /builds/omniverse/usd-ci/USD/pxr/usd/usdGeom/xformable
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 31
#      28     simulation_app.update()
#      29 timeline.pause()
# ---> 31 panel_test.update(stage, 100*i) ### CHANGED
#      33 #panel_test.update_power_produced(stage)
#      34 #print(panel_test.power_produced)
#      35 #panel_test.update_state(100)
#      36 battery_charge.append(panel_test.current_storage)
#
# File ~/Downloads/SolarPanel and Dust/Panel_Class.py:57, in Panel.update(self, stage, time_elapsed)
#      55     self.lunar_dust.update(self.timeline.get_current_time(), self.prim_path)
#      56     self.dust_coverage = self.lunar_dust.coverage
# ---> 57 self.update_power_produced(stage)
#      58 self.update_state(time_elapsed)
#
# File ~/Downloads/SolarPanel and Dust/Panel_Class.py:94, in Panel.update_power_produced(self, stage)
#      92 mesh_prim = stage.GetPrimAtPath(self.prim_path)
#      93 world_prim = stage.GetPrimAtPath("/World")
# ---> 94 points_world = mesh_utils.get_mesh_vertices_relative_to(mesh_prim, world_prim)
#      96 # Get quad centers
#      97 num_quads = len(face_vertex_indices) // 4
#
# File ~/Omniverse/library/isaac-sim-4.2.0/exts/omni.isaac.core/omni/isaac/core/utils/mesh.py:56, in get_mesh_vertices_relative_to(mesh_prim, coord_prim)
#      54 vertices_vec3f = UsdGeom.Mesh(mesh_prim).GetPointsAttr().Get()
#      55 vertices = np.array(vertices_vec3f)
# ---> 56 vertices_tf_row_major = np.pad(vertices, ((0, 0), (0, 1)), constant_values=1.0)
#      58 # Transformation matrix from the coordinate system of the mesh to the coordinate system of the prim
#      59 relative_tf_column_major = get_relative_transform(mesh_prim, coord_prim)
#
# File ~/Omniverse/library/isaac-sim-4.2.0/extscache/omni.kit.pip_archive-0.0.0+10a4b5c0.lx64.cp310/pip_prebundle/numpy/lib/arraypad.py:748, in pad(array, pad_width, mode, **kwargs)
#     745     raise TypeError('`pad_width` must be of integral type.')
#     747 # Broadcast to shape (array.ndim, 2)
# --> 748 pad_width = _as_pairs(pad_width, array.ndim, as_index=True)
#     750 if callable(mode):
#     751     # Old behavior: Use user-supplied function with np.apply_along_axis
#     752     function = mode
#
# File ~/Omniverse/library/isaac-sim-4.2.0/extscache/omni.kit.pip_archive-0.0.0+10a4b5c0.lx64.cp310/pip_prebundle/numpy/lib/arraypad.py:522, in _as_pairs(x, ndim, as_index)
#     518     raise ValueError("index can't contain negative values")
#     520 # Converting the array with `tolist` seems to improve performance
#     521 # when iterating and indexing the result (see usage in `pad`)
# --> 522 return np.broadcast_to(x, (ndim, 2)).tolist()
#
# File ~/Omniverse/library/isaac-sim-4.2.0/extscache/omni.kit.pip_archive-0.0.0+10a4b5c0.lx64.cp310/pip_prebundle/numpy/lib/stride_tricks.py:413, in broadcast_to(array, shape, subok)
#     367 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     368 def broadcast_to(array, shape, subok=False):
#     369     """Broadcast an array to a new shape.
#     370
#     371     Parameters
#    (...)
#     411            [1, 2, 3]])
#     412     """
# --> 413     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~/Omniverse/library/isaac-sim-4.2.0/extscache/omni.kit.pip_archive-0.0.0+10a4b5c0.lx64.cp310/pip_prebundle/numpy/lib/stride_tricks.py:349, in _broadcast_to(array, shape, subok, readonly)
#     346     raise ValueError('all elements of broadcast shape must be non-'
#     347                      'negative')
#     348 extras = []
# --> 349 it = np.nditer(
#     350     (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     351     op_flags=['readonly'], itershape=shape, order='C')
#     352 with it:
#     353     # never really has writebackifcopy semantics
#     354     broadcast = it.itviews[0]
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (2,2)  and requested shape (0,2)

# %%
prims_utils.delete_prim(panel_prim_path)
world.render()

usd_path = f"omniverse://localhost/Users/ubuntu/solar_panel_final_turned.usd"
panel_prim_path = prim_path + "/Panel"

panel_structure = prims_utils.create_prim(prim_path=panel_prim_path, usd_path=usd_path, scale=[20,20,20], position = [20, -40, 15])
world.render()

panel = prims_utils.get_prim_at_path(panel_prim_path)

dust_model = LunarDust(world)

panel_path = panel_prim_path + "/cilindro_est_centro/pannello_base"
panel_color_path = panel_prim_path + "/_materials/Material/Principled_BSDF" 
panel = prim.GetPrimAtPath(panel_path)

dust_model.update(0, panel)
dust_model.update_color(panel_color_path)
original_color = dust_model.original_color
# Out:
# DUST COVERAGE LIMITED BY DUST SIZE
# Max surface coverage for  4e-05  m dust:  0.10867968750000001
# Time Passed:  0.0  minutes
# Altitude:  28.5  m
# Taux de deposition:  7.86  micrograms/cm^2*y
# Covered surface by dust:  0.0 %

# %%
# TESTING WITH INPUT TIME AND PANEL CLASS


panel_prim_path = prim_path + "/Panel/Solar_Generator/Panel"
panel_test = Panel(panel_prim_path)
dust_model.reduction_altitude = 26.5
i=0
coverage_points = []
time_points = []
while i < 200:
    
    
    panel_test.update(stage, 100*i)
    panel_test.display_state()
    i+=1
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 5
#       1 # TESTING WITH INPUT TIME AND PANEL CLASS
#       4 panel_prim_path = prim_path + "/Panel/Solar_Generator/Panel"
# ----> 5 panel_test = Panel(panel_prim_path)
#       6 dust_model.reduction_altitude = 26.5
#       7 i=0
#
# File ~/Downloads/SolarPanel and Dust/Panel_Class.py:25, in Panel.__init__(self, panel_prim_path, sun_path, nb_cells, max_storage, current_storage, power_consumption, power_produced, dust_coverage, dust, timeline)
#      23 self.prim_path = panel_prim_path
#      24 self.sun_path = sun_path
# ---> 25 self.length, self.width, self.height = prims_utils.get_prim_attribute_value(panel_prim_path, "xformOp:scale")
#      26 self.panel_surface = self.length * self.width
#      27 self.nb_cells = nb_cells
#
# File ~/Omniverse/library/isaac-sim-4.2.0/exts/omni.isaac.core/omni/isaac/core/utils/prims.py:131, in get_prim_attribute_value(prim_path, attribute_name, fabric)
#     108 def get_prim_attribute_value(prim_path: str, attribute_name: str, fabric: bool = False) -> typing.Any:
#     109     """Get a prim attribute value
#     110
#     111     Args:
#    (...)
#     129         1.0
#     130     """
# --> 131     attr = get_prim_at_path(prim_path=prim_path, fabric=fabric).GetAttribute(attribute_name)
#     132     if fabric:
#     133         type_name = str(attr.GetTypeName().GetAsString())
#
# RuntimeError: Accessed invalid null prim

# %% [markdown]
# # Testing with Simulation Time

# %%
prims_utils.delete_prim(panel_prim_path)
world.render()

usd_path = f"omniverse://localhost/Users/ubuntu/solar_panel_final_turned.usd"
panel_prim_path = prim_path + "/Panel"

panel_structure = prims_utils.create_prim(prim_path=panel_prim_path, usd_path=usd_path, scale=[20,20,20], position = [20, -40, 15])
world.render()

panel = prims_utils.get_prim_at_path(panel_prim_path)

dust_model = LunarDust(world)

panel_path = panel_prim_path + "/cilindro_est_centro/pannello_base"
panel_color_path = panel_prim_path + "/_materials/Material/Principled_BSDF" 
panel = prim.GetPrimAtPath(panel_path)

dust_model.update(0, panel)
dust_model.update_color(panel_color_path)
original_color = dust_model.original_color
# Out:
# DUST COVERAGE LIMITED BY DUST SIZE
# Max surface coverage for  4e-05  m dust:  0.10867968750000001
# Time Passed:  0.0  minutes
# Altitude:  28.5  m
# Taux de deposition:  7.86  micrograms/cm^2*y
# Covered surface by dust:  0.0 %

# %%
# LUNAR DUST TESTING WITH SIMULATION TIME

import omni.timeline
dust_model.reduction_altitude = 11.5 #######
timeline = omni.timeline.get_timeline_interface()
timeline.play()

dust_model = LunarDust(world)
dust_model.reset_accumulation()

j=0
last_lunar_dust_call = timeline.get_current_time()
while j<1000000:
    current_time = timeline.get_current_time()
    #print(current_time)


    if current_time - last_lunar_dust_call > 5:
        dust_model.update(current_time, panel_structure)
        dust_model.update_color(panel_color_path)
        last_lunar_dust_call = current_time

    current_time = timeline.get_current_time()
    simulation_app.update()

    j+=1
# Out:
# DUST COVERAGE LIMITED BY DUST SIZE
# Max surface coverage for  4e-05  m dust:  0.10867968750000001
# Time Passed:  0.08  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  6.7354458372363e-08 %
#
# Time Passed:  0.17  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  1.3382267387140545e-07 %
#
# Time Passed:  0.25  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  2.0029088937044787e-07 %
#
# Time Passed:  0.33  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  2.667591048694903e-07 %
#
# Time Passed:  0.42  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  3.3322732036853275e-07 %
#
# Time Passed:  0.5  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  3.9969553586757526e-07 %
#
# Time Passed:  0.58  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  4.661637513666177e-07 %
#
# Time Passed:  0.67  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  5.326319668656602e-07 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Omniverse/library/isaac-sim-4.2.0/kit/kernel/py/omni/kit/app/_impl/app_iface.py:47, in _next_update_async.<locals>.on_event(e)
#      43 order = UPDATE_ORDER_PYTHON_ASYNC_FUTURE_END_UPDATE
#      45 f = asyncio.Future()
# ---> 47 def on_event(e: carb.events.IEvent):
#      48     if not f.done():
#      49         f.set_result(e.payload["dt"])
#
# KeyboardInterrupt:
# 2025-03-04 17:55:48 [829,890ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:55:48 [829,890ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:55:48 [829,890ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:55:48 [829,890ms] [Warning] [omni.usd] Coding Error: in _Get at line 3003 of /builds/omniverse/usd-ci/USD/pxr/usdImaging/usdImaging/delegate.cpp -- Failed verification: ' prim '
#
# 2025-03-04 17:56:02 [843,972ms] [Warning] [omni.usd] Coding Error: in AddXformOp at line 190 of /builds/omniverse/usd-ci/USD/pxr/usd/usdGeom/xformable.cpp -- The xformOp 'xformOp:translate' already exists in xformOpOrder [[xformOp:translate, xformOp:rotateXYZ, xformOp:scale]].
#
# 2025-03-04 17:56:02 [843,972ms] [Warning] [omni.usd] Coding Error: in AddXformOp at line 224 of /builds/omniverse/usd-ci/USD/pxr/usd/usdGeom/xformable.cpp -- Unable to add xform op of type TypeOrient and precision PrecisionFloat on prim at path </World/Lunar_Base/Panel/cilindro_est_centro>. opSuffix=, isInverseOp=0
#
# 2025-03-04 17:56:02 [843,972ms] [Warning] [omni.usd] Coding Error: in AddXformOp at line 190 of /builds/omniverse/usd-ci/USD/pxr/usd/usdGeom/xformable.cpp -- The xformOp 'xformOp:scale' already exists in xformOpOrder [[xformOp:translate, xformOp:rotateXYZ, xformOp:scale]].
# 2025-03-04 17:56:29 [871,032ms] [Error] [omni.ui.scene.python] KeyboardInterrupt: <EMPTY MESSAGE>
#
# At:
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/extsPhysics/omni.usdphysics.ui/omni/usdphysicsui/scripts/immediateModeViewportOverlays.py(65): _get_amended_projection
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/extsPhysics/omni.usdphysics.ui/omni/usdphysicsui/scripts/immediateModeViewportOverlays.py(88): on_build
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py(510): update
#   /tmp/ipykernel_405449/1080224753.py(24): <module>
#   /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3577): run_code
#   /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3517): run_ast_nodes
#   /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3334): run_cell_async
#   /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py(128): _pseudo_sync_runner
#   /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3130): _run_cell
#   /home/ubuntu/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3075): run_cell
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py(549): run_cell
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py(449): do_execute
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py(778): execute_request
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py(362): execute_request
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py(437): dispatch_shell
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py(534): process_one
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py(545): dispatch_queue
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/asyncio/events.py(80): _run
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/exts/omni.isaac.core_archive/pip_prebundle/nest_asyncio.py(120): _run_once
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/asyncio/base_events.py(603): run_forever
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/exts/omni.isaac.core_archive/pip_prebundle/tornado/platform/asyncio.py(215): start
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py(739): start
#   /home/ubuntu/.local/lib/python3.10/site-packages/traitlets/config/application.py(1075): launch_instance
#   /home/ubuntu/.local/lib/python3.10/site-packages/ipykernel_launcher.py(18): <module>
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/runpy.py(86): _run_code
#   /home/ubuntu/Omniverse/library/isaac-sim-4.2.0/kit/python/lib/python3.10/runpy.py(196): _run_module_as_main
# Time Passed:  0.75  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  5.991001823647026e-07 %
#
# Time Passed:  0.83  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  6.655683978637451e-07 %
#
# Time Passed:  0.92  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  7.320366133627875e-07 %
#
# Time Passed:  1.0  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  7.9850482886183e-07 %
#
# Time Passed:  1.08  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  8.649730443608724e-07 %
#
# Time Passed:  1.17  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  9.314412598599147e-07 %
#
# Time Passed:  1.25  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  9.97909475358957e-07 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Omniverse/library/isaac-sim-4.2.0/kit/kernel/py/omni/kit/app/_impl/app_iface.py:47, in _next_update_async.<locals>.on_event(e)
#      43 order = UPDATE_ORDER_PYTHON_ASYNC_FUTURE_END_UPDATE
#      45 f = asyncio.Future()
# ---> 47 def on_event(e: carb.events.IEvent):
#      48     if not f.done():
#      49         f.set_result(e.payload["dt"])
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Omniverse/library/isaac-sim-4.2.0/kit/kernel/py/omni/kit/app/_impl/app_iface.py:47, in _next_update_async.<locals>.on_event(e)
#      43 order = UPDATE_ORDER_PYTHON_ASYNC_FUTURE_END_UPDATE
#      45 f = asyncio.Future()
# ---> 47 def on_event(e: carb.events.IEvent):
#      48     if not f.done():
#      49         f.set_result(e.payload["dt"])
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Omniverse/library/isaac-sim-4.2.0/kit/kernel/py/omni/kit/app/_impl/app_iface.py:47, in _next_update_async.<locals>.on_event(e)
#      43 order = UPDATE_ORDER_PYTHON_ASYNC_FUTURE_END_UPDATE
#      45 f = asyncio.Future()
# ---> 47 def on_event(e: carb.events.IEvent):
#      48     if not f.done():
#      49         f.set_result(e.payload["dt"])
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Omniverse/library/isaac-sim-4.2.0/kit/kernel/py/omni/kit/app/_impl/app_iface.py:47, in _next_update_async.<locals>.on_event(e)
#      43 order = UPDATE_ORDER_PYTHON_ASYNC_FUTURE_END_UPDATE
#      45 f = asyncio.Future()
# ---> 47 def on_event(e: carb.events.IEvent):
#      48     if not f.done():
#      49         f.set_result(e.payload["dt"])
#
# KeyboardInterrupt:
# Time Passed:  1.33  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  1.0643776908579994e-06 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Omniverse/library/isaac-sim-4.2.0/kit/kernel/py/omni/kit/app/_impl/app_iface.py:47, in _next_update_async.<locals>.on_event(e)
#      43 order = UPDATE_ORDER_PYTHON_ASYNC_FUTURE_END_UPDATE
#      45 f = asyncio.Future()
# ---> 47 def on_event(e: carb.events.IEvent):
#      48     if not f.done():
#      49         f.set_result(e.payload["dt"])
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Omniverse/library/isaac-sim-4.2.0/kit/kernel/py/omni/kit/app/_impl/app_iface.py:47, in _next_update_async.<locals>.on_event(e)
#      43 order = UPDATE_ORDER_PYTHON_ASYNC_FUTURE_END_UPDATE
#      45 f = asyncio.Future()
# ---> 47 def on_event(e: carb.events.IEvent):
#      48     if not f.done():
#      49         f.set_result(e.payload["dt"])
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Omniverse/library/isaac-sim-4.2.0/exts/omni.isaac.core/omni/isaac/core/simulation_context/simulation_context.py:1394, in SimulationContext._physics_timer_callback_fn(self, step_size)
#    1388     return
#    1390 """
#    1391 Default Callbacks.
#    1392 """
# -> 1394 def _physics_timer_callback_fn(self, step_size: int):
#    1395     self._current_time += step_size
#    1396     self._number_of_steps += 1
#
# KeyboardInterrupt:
# Time Passed:  1.42  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  1.1308459063570419e-06 %
#
# Time Passed:  1.5  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  1.1973141218560842e-06 %
#
# Time Passed:  1.58  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  1.2637823373551267e-06 %
#
# Time Passed:  1.67  minutes
# Altitude:  7.57  m
# Taux de deposition:  16.77  micrograms/cm^2*y
# Covered surface by dust:  1.330250552854169e-06 %

# %%
# TESTING WITH SIMULATION TIME AND PANEL CLASS

import omni.timeline

timeline = omni.timeline.get_timeline_interface()
timeline.play()

import omni.isaac.core.utils.rotations as rotations_utils
dust_model.reduction_altitude = 6.5
panel_prim_path = prim_path + "/Panel/Solar_Generator/Panel"
panel_test = Panel(panel_prim_path)

j=0
last_lunar_dust_call = timeline.get_current_time()
while j<100000:
    current_time = timeline.get_current_time()
    #print(previous_time)


    if current_time - last_lunar_dust_call > 100:
        print("Current time: ", current_time)
        print("")
        print(current_time - last_lunar_dust_call)
        panel_test.update(stage, current_time)
        panel_test.display_state()
        print("----------------------------------------------------------------------------------------")
        last_lunar_dust_call = current_time

    current_time = timeline.get_current_time()
    simulation_app.update()

    j+=1

# %% [markdown]
# # Scrapped
